# %% [markdown]
# # Assignment 2

# %% [markdown]
# ##Data Visualization and Pre-processing

# %% [markdown]
# ###*1. Perform Below Visualizations.*
#
# ---

# %% [markdown]
# Univariate Analysis
#
# 1. Summary Statistics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### *2. Reading the dataset*
#
# ---

# %%
data = pd.read_csv(r'/content/Churn_Modelling.csv')
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### *Univariate Analysis*
#
# ---
#
#
#
# 1. Summary Statistics

# %%
print("The mean of the dataset is : ",data['Balance'].mean())
print("The median of the dataset is : ",data['Balance'].median())
print("The std of the dataset is : ",data['Balance'].std())
# Out:
# The mean of the dataset is :  76485.889288
# The median of the dataset is :  97198.54000000001
# The std of the dataset is :  62397.405202385955

# %% [markdown]
# ### *2.Frequency Table*
#
# ---

# %%
data['Surname'].value_counts()
# Out:
# Smith       32
# Scott       29
# Martin      29
# Walker      28
# Brown       26
#             ..
# Izmailov     1
# Bold         1
# Bonham       1
# Poninski     1
# Burbidge     1
# Name: Surname, Length: 2932, dtype: int64

# %% [markdown]
# ### *3. Create Charts*
#
# ---

# %%
data.boxplot(column=['Balance'], grid=True,color="orange")

# %%
data.hist(column='Balance',edgecolor='black',color="yellow")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a373590d0>]],
#       dtype=object)

# %%
sns.kdeplot(data['Balance'],color="orange")

# %% [markdown]
# ## Bi - Variate Analysis
#
# ---

# %% [markdown]
# ### *1. Scatterplots*
#
# ---

# %%
plt.scatter(data.CreditScore.head(100),data.Age.head(100))
plt.title('Scatter')
plt.xlabel('CreditScore')
plt.ylabel('Balance')
# Out:
# Text(0, 0.5, 'Balance')

# %% [markdown]
# ### *2. Simple Linear Regression*
#
# ---

# %%
plt.plot(data['RowNumber'].head() ,data['CreditScore'].head(), color="orange" )

plt.title('Line plot')
plt.xlabel('RowNumber')
plt.ylabel('CreditScore')
# Out:
# Text(0, 0.5, 'CreditScore')

# %% [markdown]
# ## Multi - Variate Analysis

# %%
mulvar = plt.subplots(figsize=(10,8))
sns.heatmap(data.head().corr(), cmap="RdPu",annot=True)

# %% [markdown]
# ### *4. Descriptive Statistics*
#
# ---

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# 5. Handle the Missing values
#
# ---

# %%
data.isnull().any()
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ### *6 - Find Outliers and Replacing*
#
# ---

# %%
sns.boxplot(x=data["CreditScore"])

# %%
q1 = data.CreditScore.quantile(0.25)
q2 = data.CreditScore.quantile(0.75)
iq = q2 - q1
u_limit = q2+1.5*iq
l_limit = q1-1.5*iq

# %%
data.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# RowNumber          5.000500e+03
# CustomerId         1.569074e+07
# CreditScore        6.520000e+02
# Age                3.700000e+01
# Tenure             5.000000e+00
# Balance            9.719854e+04
# NumOfProducts      1.000000e+00
# HasCrCard          1.000000e+00
# IsActiveMember     1.000000e+00
# EstimatedSalary    1.001939e+05
# Exited             0.000000e+00
# dtype: float64

# %%
q1 = data.CreditScore.quantile(0.25)
q2 = data.CreditScore.quantile(0.75)
iq = q2 - q1
u_limit = q2+1.5*iq
l_limit = q1-1.5*iq
print(l_limit)
print(u_limit)
data["CreditScore"].head
# Out:
# 383.0
# 919.0
# <bound method NDFrame.head of 0       619
# 1       608
# 2       502
# 3       699
# 4       850
#        ...
# 9995    771
# 9996    516
# 9997    709
# 9998    772
# 9999    792
# Name: CreditScore, Length: 10000, dtype: int64>

# %%
data["CreditScore"] = np.where(data["CreditScore"]<l_limit,6.52,data["CreditScore"])
data["CreditScore"] = np.where(data["CreditScore"]<l_limit,6.52,data["CreditScore"])
sns.violinplot(x=data["CreditScore"])

# %% [markdown]
# ### *7. Categorical Columns and perform Encoding*
#
# ---

# %%
data.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave       619.00    France  Female   42
# 1          2    15647311      Hill       608.00     Spain  Female   41
# 2          3    15619304      Onio       502.00    France  Female   42
# 3          4    15701354      Boni       699.00    France  Female   39
# 4          5    15737888  Mitchell       850.00     Spain  Female   43
# 5          6    15574012       Chu       645.00     Spain    Male   44
# 6          7    15592531  Bartlett       822.00    France    Male   50
# 7          8    15656148    Obinna         6.52   Germany  Female   29
# 8          9    15792365        He       501.00    France    Male   44
# 9         10    15592389        H?       684.00    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
print(data.Surname.unique())
print(data.Geography.unique())
print(data.Gender.unique())
print(data.Tenure.unique())
# Out:
# ['Hargrave' 'Hill' 'Onio' ... 'Kashiwagi' 'Aldridge' 'Burbidge']
# ['France' 'Spain' 'Germany']
# ['Female' 'Male']
# [ 2  1  8  7  4  6  3 10  5  9  0]

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc = LabelEncoder()
data.Surname = lab_enc.fit_transform(data.Surname)
data.Geography = lab_enc.fit_transform(data.Geography)
data.Gender = lab_enc.fit_transform(data.Gender)
data.head(5)
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602     1115        619.0          0       0   42
# 1          2    15647311     1177        608.0          2       0   41
# 2          3    15619304     2040        502.0          0       0   42
# 3          4    15701354      289        699.0          0       0   39
# 4          5    15737888     1822        850.0          2       0   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %% [markdown]
# ### *8. Split the Data into Dependent and Independent Variables*
#
# ---

# %%
y = data["EstimatedSalary"]
X = data.drop("EstimatedSalary",axis=1)
y
# Out:
# 0       101348.88
# 1       112542.58
# 2       113931.57
# 3        93826.63
# 4        79084.10
#           ...
# 9995     96270.64
# 9996    101699.77
# 9997     42085.58
# 9998     92888.52
# 9999     38190.78
# Name: EstimatedSalary, Length: 10000, dtype: float64

# %%
x
# Out:
#       const  IsActiveMember
# 0       1.0               1
# 1       1.0               1
# 2       1.0               0
# 3       1.0               0
# 4       1.0               1
# ...     ...             ...
# 9995    1.0               0
# 9996    1.0               1
# 9997    1.0               1
# 9998    1.0               0
# 9999    1.0               0
#
# [10000 rows x 2 columns]

# %% [markdown]
# ### *9. Scale the Independent Variables*
#
# ---

# %%
from sklearn.preprocessing import scale
scaled_X = pd.DataFrame(scale(X),columns=X.columns)
scaled_X
# Out:
#       RowNumber  CustomerId   Surname  CreditScore  Geography    Gender  \
# 0     -1.731878   -0.783213 -0.464183    -0.312521  -0.901886 -1.095988
# 1     -1.731531   -0.606534 -0.390911    -0.423428   1.515067 -1.095988
# 2     -1.731185   -0.995885  0.628988    -1.492167  -0.901886 -1.095988
# 3     -1.730838    0.144767 -1.440356     0.494074  -0.901886 -1.095988
# 4     -1.730492    0.652659  0.371354     2.016523   1.515067 -1.095988
# ...         ...         ...       ...          ...        ...       ...
# 9995   1.730492   -1.177652  0.580534     1.220010  -0.901886  0.912419
# 9996   1.730838   -1.682806 -0.203004    -1.351013  -0.901886  0.912419
# 9997   1.731185   -1.479282  0.073539     0.594899  -0.901886 -1.095988
# 9998   1.731531   -0.119356  0.989439     1.230092   0.306591  0.912419
# 9999   1.731878   -0.870559  1.469253     1.431741  -0.901886 -1.095988
#
#            Age    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# ### *10. Split the Data into Training and Testing*
#
# ---

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, ytrain, ytest = train_test_split(scaled_X, y, test_size=0.3, random_state=0)
print(Xtrain.shape, Xtest.shape, ytrain.shape, ytest.shape)
Xtrain
# Out:
# (7000, 13) (3000, 13) (7000,) (3000,)
#       RowNumber  CustomerId   Surname  CreditScore  Geography    Gender  \
# 7681   0.928899   -0.797032 -1.475810    -0.090708  -0.901886  0.912419
# 9031   1.396553    0.714314 -1.588081    -1.098952  -0.901886  0.912419
# 3691  -0.453278    0.963450 -0.240822    -0.604912  -0.901886 -1.095988
# 202   -1.661903   -1.250707 -0.427547    -1.351013   1.515067  0.912419
# 5625   0.216680   -0.385174 -1.478173    -1.431672  -0.901886 -1.095988
# ...         ...         ...       ...          ...        ...       ...
# 9225   1.463756   -1.473777  1.385344    -0.564582   0.306591 -1.095988
# 4859  -0.048671   -0.609314  1.530707     1.451906   1.515067 -1.095988
# 3264  -0.601195   -1.620525 -0.361366     0.887289  -0.901886  0.912419
# 9845   1.678530   -0.374039  0.725896    -0.604912   1.515067 -1.095988
# 2732  -0.785485   -1.364118  1.382981    -0.272191   0.306591 -1.095988
#
# ...

# %%
Xtrain
# Out:
#       RowNumber  CustomerId   Surname  CreditScore  Geography    Gender  \
# 7681   0.928899   -0.797032 -1.475810    -0.090708  -0.901886  0.912419
# 9031   1.396553    0.714314 -1.588081    -1.098952  -0.901886  0.912419
# 3691  -0.453278    0.963450 -0.240822    -0.604912  -0.901886 -1.095988
# 202   -1.661903   -1.250707 -0.427547    -1.351013   1.515067  0.912419
# 5625   0.216680   -0.385174 -1.478173    -1.431672  -0.901886 -1.095988
# ...         ...         ...       ...          ...        ...       ...
# 9225   1.463756   -1.473777  1.385344    -0.564582   0.306591 -1.095988
# 4859  -0.048671   -0.609314  1.530707     1.451906   1.515067 -1.095988
# 3264  -0.601195   -1.620525 -0.361366     0.887289  -0.901886  0.912419
# 9845   1.678530   -0.374039  0.725896    -0.604912   1.515067 -1.095988
# 2732  -0.785485   -1.364118  1.382981    -0.272191   0.306591 -1.095988
#
#            Age    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
Xtest
# Out:
#       RowNumber  CustomerId   Surname  CreditScore  Geography    Gender  \
# 9394   1.522299   -1.045250  1.398344    -0.534335   0.306591 -1.095988
# 898   -1.420801   -0.503813 -0.782089    -1.280436  -0.901886 -1.095988
# 2398  -0.901186   -0.793292  0.412717     0.564651   1.515067 -1.095988
# 5906   0.314021    0.760190  1.590979     1.391412  -0.901886  0.912419
# 2343  -0.920239    1.042107 -0.603636     0.564651   0.306591  0.912419
# ...         ...         ...       ...          ...        ...       ...
# 4004  -0.344851    0.661806 -0.626091    -1.209859   1.515067 -1.095988
# 7375   0.822897   -0.723866 -1.266630    -0.110872  -0.901886  0.912419
# 9307   1.492162   -0.146464  0.686897     0.352920  -0.901886  0.912419
# 8394   1.175889   -1.292287 -1.384811     0.423497  -0.901886  0.912419
# 5233   0.080887   -1.385388  1.117074     0.816712   0.306591 -1.095988
#
#            Age    Tenure   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
ytrain
# Out:
# 7681     55796.83
# 9031     19823.02
# 3691     13848.58
# 202     146145.93
# 5625    129562.74
#           ...
# 9225    162961.79
# 4859    107753.07
# 3264    181429.87
# 9845    148750.16
# 2732    118855.26
# Name: EstimatedSalary, Length: 7000, dtype: float64

# %%
ytest
# Out:
# 9394    192852.67
# 898     128702.10
# 2398     75732.25
# 5906     89368.59
# 2343    135662.17
#           ...
# 4004    147606.71
# 7375     55829.25
# 9307    167400.29
# 8394     70849.47
# 5233     33759.41
# Name: EstimatedSalary, Length: 3000, dtype: float64
